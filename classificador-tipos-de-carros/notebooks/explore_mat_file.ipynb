# %% [markdown]
# # Explorar o conteúdo do arquivo .mat
# Neste arquivo estão contidos os metadados do dataset utilizado nessa tark de classificação de tipos de carros

# %% [markdown]
# Importar bibliotecas

# %%
import scipy.io
import pandas as pd

# %% [markdown]
# Leitura do arquivo .mat

# %%
mat_file_path = '/home/leticia/projetos/Avaliacao-MOBIT/classificador-tipos-de-carros/data/raw/bmw10_annos.mat'
mat_file = scipy.io.loadmat(mat_file_path)

# %% [markdown]
# Exibir conteúdo do arquivo

# %%
# Chaves do dicionario. Vamos utilizar as informacoes contidas nas chaves 'train_indices', 'test_indices', 'annos'
mat_file.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'train_indices', 'test_indices', 'annos'])

# %% [markdown]
# Na estrutura da chave 'annos', os atributos da imagem estão organizados na ordem: **('fname'), ('class'), ('bbox_x1'), ('bbox_x2'), ('bbox_y1'), ('bbox_y2'), ('height'), ('width')**

# %%
# Estrutura do chave annos
mat_file['annos'][0][100]
# Out:
# np.void((array(['1/150083295.jpg'], dtype='<U15'), array([[1]], dtype=uint8), array([[13]], dtype=int32), array([[449]], dtype=int32), array([[33]], dtype=int32), array([[321]], dtype=int32), array([[421]], dtype=uint16), array([[562]], dtype=uint16)), dtype=[('fname', 'O'), ('class', 'O'), ('bbox_x1', 'O'), ('bbox_x2', 'O'), ('bbox_y1', 'O'), ('bbox_y2', 'O'), ('height', 'O'), ('width', 'O')])

# %%
mat_file['annos'][0]
# Out:
# array([(array(['10/150302307.thumb.jpg'], dtype='<U22'), array([[9]], dtype=uint8), array([[42]], dtype=int32), array([[217]], dtype=int32), array([[32]], dtype=int32), array([[163]], dtype=int32), array([[183]], dtype=uint8), array([[275]], dtype=uint16)),
#        (array(['10/150302397.jpg'], dtype='<U16'), array([[9]], dtype=uint8), array([[299]], dtype=int32), array([[639]], dtype=int32), array([[213]], dtype=int32), array([[371]], dtype=int32), array([[426]], dtype=uint16), array([[640]], dtype=uint16)),
#        (array(['10/150302515.jpg'], dtype='<U16'), array([[9]], dtype=uint8), array([[32]], dtype=int32), array([[445]], dtype=int32), array([[41]], dtype=int32), array([[295]], dtype=int32), array([[360]], dtype=uint16), array([[480]], dtype=uint16)),
# ...
